# %% [markdown]
# <a href="https://colab.research.google.com/github/AQadir44/saylani_batch_10/blob/master/25_Nov_2025_batch_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
while i <= 5 :
  i+=1
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
flag = True

while flag:
  name = input("Enter your name")
  if name == "exit":
    flag = False
    print(f"Bye , Have a Good Day")
  else:
    print(f"Welcome, {name}")
# Out:
# Enter your nameaqsa
# Welcome, aqsa
# Enter your nameabiha
# Welcome, abiha
# Enter your nameexit
# Bye , Have a Good Day

# %%
sqr_num = []
for i in range(10):
  sqr_num.append(i**2)

# %%
sqr_num
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
sqr_num_2 = [i**2 for i in range(10) ]

# %%
sqr_num_2
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
even_num = [j for j in range(10) if j %2 == 0]

# %%
even_num
# Out:
# [0, 2, 4, 6, 8]

# %%
# i : i**2

# %%
# {1:1 , 2:4 , 3:9}

# %%
sqr_dict = { i : i**2 for i in range(10)}

# %%
sqr_dict
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
